# %% [markdown]
# <a href="https://colab.research.google.com/github/saisampaththumati-datascientists/seaborn_practices_911/blob/main/Boston_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # doctest: +SKIP
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/HousingData.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 4     0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# 6     0.08829  12.5   7.87   NaN  0.524  6.012  66.6  5.5605    5  311
# 9     0.17004  12.5   7.87   NaN  0.524  6.004  85.9  6.5921    5  311
# 14    0.63796   0.0   8.14   NaN  0.538  6.096  84.5  4.4619    4  307
# 35    0.06417   0.0   5.96   0.0  0.499  5.933  68.2  3.3603    5  279
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 473   4.64689   0.0  18.10   0.0  0.614  6.980  67.6  2.5329   24  666
# 479  14.33370   0.0  18.10   NaN  0.614  6.229  88.0  1.9512   24  666
# 482   5.73116   0.0  18.10   NaN  0.532  7.061  77.0  3.4106   24  666
# 501   0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 4       18.7  396.90    NaN  36.2
# 6       15.2  395.60  12.43  22.9
# ...

# %%
df = df.interpolate(method='linear')

# %%
# Create a condition where INDUS is equal to 7.87
condition = df['INDUS'] == 7.87

# Group by the condition and count the number of occurrences
result = df[condition].groupby('INDUS').size()
df[df['INDUS'] == 18.10]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 356  8.98296  0.0   18.1   1.0  0.770  6.212  97.4  2.1222   24  666     20.2
# 357  3.84970  0.0   18.1   1.0  0.770  6.395  91.0  2.5052   24  666     20.2
# 358  5.20177  0.0   18.1   1.0  0.770  6.127  83.4  2.7227   24  666     20.2
# 359  4.26131  0.0   18.1   0.0  0.770  6.112  81.3  2.5091   24  666     20.2
# 360  4.54192  0.0   18.1   0.0  0.770  6.398  88.0  2.5182   24  666     20.2
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 483  2.81838  0.0   18.1   0.0  0.532  5.762  40.3  4.0983   24  666     20.2
# 484  2.37857  0.0   18.1   0.0  0.583  5.871  41.9  3.7240   24  666     20.2
# 485  3.67367  0.0   18.1   0.0  0.583  6.312  51.9  3.9917   24  666     20.2
# 486  5.69175  0.0   18.1   0.0  0.583  6.114  79.8  3.5459   24  666     20.2
# 487  4.83567  0.0   18.1   0.0  0.583  5.905  53.2  3.1523   24  666     20.2
#
#           B  LSTAT  MEDV
# ...

# %%
df["CHAS"].value_counts()
# Out:
# CHAS
# 0.0    472
# 1.0     34
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x=df.drop("CHAS",axis=1)
y=df["CHAS"]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=43,shuffle=True)

# %%
y.value_counts()
# Out:
# CHAS
# 0.0    472
# 1.0     34
# Name: count, dtype: int64

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((379, 13), (127, 13), (379,), (127,))

# %%
import imblearn
from imblearn.over_sampling import SMOTE
over_sampling = SMOTE(k_neighbors=5)
x_train_over, y_train_over = over_sampling.fit_resample(x, y)

# %%
x_train_over.shape,y_train_over.shape
# Out:
# ((944, 13), (944,))

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train_over=scale.fit_transform(x_train_over)
x_test=scale.fit_transform(x_test)

# %%
y_train_over.value_counts()
# Out:
# CHAS
# 0.0    472
# 1.0    472
# Name: count, dtype: int64

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(510),  # Corrected to use 'units' and 'input_dim'
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(24, activation="relu"),
    tf.keras.layers.Dense(1,activation="sigmoid")  # This layer is for regression; for binary classification, you can use a sigmoid activation
])

call_back = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)

model.summary()

# For binary classification, use BinaryCrossentropy and sigmoid activation on the output layer
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# ...

# %%
history=model.fit(x_train_over,y_train_over,validation_data=(x_test,y_test),epochs=50,verbose=0,batch_size=10)

# %%
plt.plot(history.history["val_accuracy"])
plt.plot(history.history["val_loss"])

# %%
# y_test = y_test.flatten()  # Convert to NumPy array and flatten (if needed)
# y_predict = y_predict.flatten()  # Flatten NumPy array if it's not already 1D

# Create a DataFrame with the 1D arrays
data = pd.DataFrame({
    "y_true": y_test,
    # "y_pred": y_predict
})
data["y_predict"]=y_predict
data["difference"]=data["y_true"]-data["y_predict"]
data
# Out:
#      y_true     y_predict    difference
# 360     0.0  3.512315e-01 -3.512315e-01
# 391     0.0  6.158438e-01 -6.158438e-01
# 247     0.0  4.224722e-13 -4.224722e-13
# 57      0.0  7.153245e-10 -7.153245e-10
# 244     0.0  5.732702e-19 -5.732702e-19
# ..      ...           ...           ...
# 460     0.0  4.889586e-04 -4.889586e-04
# 384     0.0  3.252715e-13 -3.252715e-13
# 29      0.0  1.844690e-10 -1.844690e-10
# 251     0.0  1.141371e-19 -1.141371e-19
# 308     0.0  3.407179e-09 -3.407179e-09
#
# [127 rows x 3 columns]

# %%
data["binary_predictions"] = np.where(data["y_predict"] >= 0.5, 1, 0)

# %%
data=data.drop(["y_predict","difference"],axis=1)

# %%
data
# Out:
#      y_true  binary_predictions
# 360     0.0                   0
# 391     0.0                   1
# 247     0.0                   0
# 57      0.0                   0
# 244     0.0                   0
# ..      ...                 ...
# 460     0.0                   0
# 384     0.0                   0
# 29      0.0                   0
# 251     0.0                   0
# 308     0.0                   0
#
# [127 rows x 2 columns]

# %%
y_predict=data["binary_predictions"]
y_true=data["y_true"]
from sklearn.metrics import precision_score,recall_score,accuracy_score,f1_score,confusion_matrix,precision_recall_curve

precision_score=precision_score(y_test,y_predict)
recall_score=recall_score(y_test,y_predict)
accuracy_score=accuracy_score(y_test,y_predict)
f1_score=f1_score(y_test,y_predict)
precision_score,recall_score,accuracy_score,accuracy_score
# Out:
# (0.6, 0.8181818181818182, 0.937007874015748, 0.937007874015748)

# %%
from sklearn.model_selection import GridSearchCV,KFold
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %%
sns.scatterplot(y_test)
sns.scatterplot(y_predict)
# Out:
# <Axes: ylabel='CHAS'>
